# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X, y = datasets.make_blobs (n_samples=150, n_features=2,centers=2, cluster_std=1.05,random_state=2)
#Plotting
fig = plt.figure(figsize=(10,8))
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'r^')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
def acti_func(z):
    if(z>0):
        return 1
    return 0

# %%
def perceptron(X, y, lr, epochs):
 # X --> Inputs.
 # y --> labels/target.
 # lr --> learning rate.
 # epochs --> Number of iterations.
 # m-> number of training examples
 # n-> number of features
    m, n = X.shape
 # Initializing parameters(theta) to zeros.
 # +1 in n+1 for the bias term.
    w = np.zeros((n+1,1))
 # Empty list to store how many examples were
 # misclassified at every iteration.
    n_miss_list = []
 # Training.
    for epoch in range(epochs):
 # variable to store #misclassified.
        n_miss = 0
# looping for every example.
        for idx, x_i in enumerate(X):
 # Insering 1 for bias, X0 = 1.
            x_i = np.insert(x_i, 0, 1).reshape(-1,1)
 # Calculating prediction/hypothesis.
            y_hat = acti_func(np.dot(x_i.T, w))
 # Updating if the example is misclassified.
            if (np.squeeze(y_hat) - y[idx]) != 0:
                w = w+lr*(y[idx]-y_hat)*x_i
 # Incrementing by 1.
                n_miss+=1
 # Appending number of misclassified examples
 # at every iteration.
        n_miss_list.append(n_miss)
    return w, n_miss_list

# %%
w,miss=perceptron(X, y, 0.01, 3)
print(miss)
print(w)
# Out:
# [14, 0, 0]
# [[0.1       ]
#  [0.01488595]
#  [0.01693843]]

# %%
def plot_decision_boundary(X, w):

 # X --> Inputs
 # w --> parameters

 # The Line is y=mx+c
 # So, Equate mx+c = w0.X0 + w1.X1 + w2.X2
 # Solving we find m and c
    x1 = [min(X[:,0]), max(X[:,0])]
    m = -w[1]/w[2]
    c = -w[0]/w[2]
    x2 = m*x1 + c

 # Plotting
    plt.plot(x1, x2, color='g', label='Decision Boundary')
    plt.legend()
    plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'r^')
    plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
    plt.xlabel("feature 1")
    plt.ylabel("feature 2")
    plt.title('Random Classification Data with 2 classes')
    plt.show()

# %%
plot_decision_boundary(X, w)

# %%
#Exercice2

# %%
from sklearn.utils import shuffle

X1, y1 = datasets.make_blobs(n_samples=125, n_features=2, centers=1, cluster_std=0.25, random_state=2, center_box=(1,0))
X2, y2 = datasets.make_blobs(n_samples=125, n_features=2, centers=1, cluster_std=0.25, random_state=2,center_box=(-1,0))
y2 = np.full((125,), -1)

# print(X1,y1)
# print(X2,y2)

X = np.concatenate((X1, X2), axis=0)
y = np.concatenate((y1, y2), axis=0)

# Shuffle the dataset
X, y = shuffle(X, y, random_state=42)

# print("X shape:", X.shape)
# print("y shape:", y.shape)

# %%
# Plotting
fig = plt.figure(figsize=(10, 8))

# Plot points with label 0 in red triangles ('r^')
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'r^', label='Class 0')

# Plot points with label -1 in blue squares ('bs') - Corrected here
plt.plot(X[:, 0][y == -1], X[:, 1][y == -1], 'bs', label='Class -1')

# Set labels for the x and y axes
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")

# Set the title of the plot
plt.title('Random Classification Data with 2 classes')

# Display a legend in the plot
plt.legend()

# Show the plot
plt.show()

# %%
w,min=perceptron(X, y, 0.01, 3)

# %%
# plot_decision_boundary(X, w)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 plot_decision_boundary(X, w)
#
# Cell In[52], line 9, in plot_decision_boundary(X, w)
#       1 def plot_decision_boundary(X, w):
#       2
#       3  # X --> Inputs
#    (...)
#       7  # So, Equate mx+c = w0.X0 + w1.X1 + w2.X2
#       8  # Solving we find m and c
# ----> 9     x1 = [min(X[:,0]), max(X[:,0])]
#      10     m = -w[1]/w[2]
#      11     c = -w[0]/w[2]
#
# TypeError: 'list' object is not callable
